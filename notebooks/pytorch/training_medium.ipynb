# %% [markdown]
# ## Animal Classifier (4.5M Parameter model)
# Training an image classification model using pytorch

# %%
import os
from pathlib import Path

import torch, torchvision
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
import torch.optim as optim

import matplotlib.pyplot as plt
import numpy as np

print(f"Pytorch version: {torch.__version__}")
# Out:
# Pytorch version: 2.1.1

# %% [markdown]
# ### SETUP

# %%
# GPU or CPU?
device = (
    "cuda" if torch.cuda.is_available()
    else "mps" if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using mps device

# %% [markdown]
# ### DATASET
# Load and clean the dataset:
# 1. Make sure the animals dataset is downloaded into the "datasets/animals" directory
#    (https://www.kaggle.com/datasets/npurav/animal-classification-dataset)
# 2. Add augmented images to the dataset.
# 3. Load the dataset then split into train and test data

# %%
# Get root directory
BASE_DIR = Path.cwd().resolve().parent.parent

# Path to your dataset
dataset_path = BASE_DIR / 'datasets/animals/dataset'

# Define transformations (you can customize these based on your needs)
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize images to a common size
    transforms.ToTensor(),
])

# Create ImageFolder dataset
dataset = ImageFolder(dataset_path, transform=transform)
class_names = dataset.classes
print(f'Total number of classes: {len(class_names)}')
# Out:
# Total number of classes: 117

# %%
# Image augmentation
# Define image transformations for augmentation
augmentation_transform = transforms.Compose([
    #transforms.RandomResizedCrop(224),        # Random crop and resize
    transforms.RandomHorizontalFlip(),        # Random horizontal flip
    transforms.RandomVerticalFlip(),          # Random vertical flip
    # transforms.RandomRotation(degrees=15),    # Random rotation (up to 15 degrees)
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),  # Color jitter
    transforms.RandomGrayscale(p=0.1),        # Randomly convert to grayscale
    transforms.RandomPerspective(distortion_scale=0.2, p=0.2),  # Random perspective
    transforms.Resize((224, 224)),
    transforms.ToTensor(),  # Convert to PyTorch tensor
])

# Create augmented dataset
for i in range(8):
    # Apply augmentation to the entire dataset
    augmented_dataset = ImageFolder(dataset_path, transform=augmentation_transform)
    # Combine the original and augmented datasets
    dataset = torch.utils.data.ConcatDataset([dataset, augmented_dataset])
    
print(f'Total number of images: {len(dataset)}')
# Out:
# Total number of images: 173025

# %%
# Split the dataset into training and testing sets

# Define the sizes for training, validation, and testing sets
train_ratio = 0.8
val_ratio = 0.1
test_ratio = 0.1

train_size = int(train_ratio * len(dataset))
val_size = int(val_ratio * len(dataset))
test_size = len(dataset) - train_size - val_size

# Split
trainset, valset, testset = torch.utils.data.random_split(dataset, [train_size, val_size, test_size])
print(f'Total number of training images: {len(trainset)}')
print(f'Total number of validation images: {len(valset)}')
print(f'Total number of test images: {len(testset)}')
# Out:
# Total number of training images: 138420
# Total number of validation images: 17302
# Total number of test images: 17303

# %%
# Create data loaders
batch_size = 64

trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=4)
valloader = torch.utils.data.DataLoader(valset, batch_size=batch_size, shuffle=False, num_workers=4)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=4)

# %% [markdown]
# Display a subset of the training images

# %%
# %%time

# function to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)

# show images
imshow(torchvision.utils.make_grid(images[0:5]))
# print labels
print(' '.join(f'{class_names[labels[j]]:5s}' for j in range(5)))
# Out:
# panthera-tigris giraffa-camelopardalis equus-caballus gallus-gallus-domesticus ovis-aries
# CPU times: user 412 ms, sys: 502 ms, total: 913 ms
# Wall time: 4.9 s

# %% [markdown]
# ### TRAINING STEP
# Define a convolution neural network

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 9, 5)
        self.pool = nn.MaxPool2d(3, 3)
        self.conv2 = nn.Conv2d(9, 32, 3)
        self.conv3 = nn.Conv2d(32, 64, 3)
        self.fc1 = nn.Linear(3136, 1200)
        self.fc2 = nn.Linear(1200, 600)
        self.fc3 = nn.Linear(600, len(class_names))

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

net = Net()
net.to(device)
print(f'Trainable params: {sum(p.numel() for p in net.parameters() if p.requires_grad)}')
# Out:
# Trainable params: 4577121

# %% [markdown]
# Define learning rate, loss function and optimizer

# %%
learning_rate = 0.005

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9)
# optimizer = optim.Adam(net.parameters(), lr=learning_rate)

# %% [markdown]
# Train the network

# %%
# %%time
epochs = 20

# Initialize an empty list to store loss values for plotting
loss_values = []
val_loss_values = []
print('Starting Training...')
for epoch in range(epochs):  # loop over the dataset multiple times
    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data[0].to(device), data[1].to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        step = 200
        if i % step == step - 1:    # print after ever "step" mini-batches
            print(f'epoch({epoch + 1}/{epochs}) batch: {i + 1} loss: {running_loss / step:.3f}')
            # Append the average loss to the list for plotting
            loss_values.append(running_loss / step)
            running_loss = 0.0

    # Calculate validation loss after each epoch
    val_running_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for data in valloader:
            val_inputs, val_labels = data[0].to(device), data[1].to(device)
            val_outputs = net(val_inputs)
            val_loss = criterion(val_outputs, val_labels)
            val_running_loss += val_loss.item()
    val_loss_values.append(val_running_loss / len(valloader))
    print(f'epoch({epoch + 1}/{epochs}) Validation loss: {val_running_loss / len(valloader)}')

print('Finished Training')
# Out:
# Starting Training...
# epoch(1/20) batch: 200 loss: 4.172
# epoch(1/20) batch: 400 loss: 3.867
# epoch(1/20) batch: 600 loss: 3.850
# epoch(1/20) batch: 800 loss: 3.817
# epoch(1/20) batch: 1000 loss: 3.750
# epoch(1/20) batch: 1200 loss: 3.657
# epoch(1/20) batch: 1400 loss: 3.538
# epoch(1/20) batch: 1600 loss: 3.382
# epoch(1/20) batch: 1800 loss: 3.291
# epoch(1/20) batch: 2000 loss: 3.161
# epoch(1/20) Validation loss: 3.0001470813891986
# epoch(2/20) batch: 200 loss: 2.961
# epoch(2/20) batch: 400 loss: 2.882
# epoch(2/20) batch: 600 loss: 2.803
# epoch(2/20) batch: 800 loss: 2.729
# epoch(2/20) batch: 1000 loss: 2.672
# epoch(2/20) batch: 1200 loss: 2.574
# epoch(2/20) batch: 1400 loss: 2.493
# epoch(2/20) batch: 1600 loss: 2.488
# epoch(2/20) batch: 1800 loss: 2.359
# epoch(2/20) batch: 2000 loss: 2.319
# epoch(2/20) Validation loss: 2.207316509911935
# epoch(3/20) batch: 200 loss: 2.182
# epoch(3/20) batch: 400 loss: 2.115
# epoch(3/20) batch: 600 loss: 2.059
# epoch(3/20) batch: 800 loss: 2.008
# epoch(3/20) batch: 1000 loss: 1.966
# epoch(3/20) batch: 1200 loss: 1.913
# epoch(3/20) batch: 1400 loss: 1.872
# epoch(3/20) batch: 1600 loss: 1.850
# epoch(3/20) batch: 1800 loss: 1.770
# epoch(3/20) batch: 2000 loss: 1.730
# epoch(3/20) Validation loss: 1.6313964308847801
# epoch(4/20) batch: 200 loss: 1.566
# epoch(4/20) batch: 400 loss: 1.517
# epoch(4/20) batch: 600 loss: 1.489
# epoch(4/20) batch: 800 loss: 1.468
# epoch(4/20) batch: 1000 loss: 1.390
# epoch(4/20) batch: 1200 loss: 1.340
# epoch(4/20) batch: 1400 loss: 1.300
# epoch(4/20) batch: 1600 loss: 1.286
# epoch(4/20) batch: 1800 loss: 1.226
# epoch(4/20) batch: 2000 loss: 1.183
# epoch(4/20) Validation loss: 1.1557755195346706
# epoch(5/20) batch: 200 loss: 1.012
# epoch(5/20) batch: 400 loss: 1.005
# epoch(5/20) batch: 600 loss: 0.989
# epoch(5/20) batch: 800 loss: 0.991
# epoch(5/20) batch: 1000 loss: 0.963
# epoch(5/20) batch: 1200 loss: 0.930
# epoch(5/20) batch: 1400 loss: 0.893
# epoch(5/20) batch: 1600 loss: 0.830
# epoch(5/20) batch: 1800 loss: 0.840
# epoch(5/20) batch: 2000 loss: 0.783
# epoch(5/20) Validation loss: 0.8657856163503499
# epoch(6/20) batch: 200 loss: 0.695
# epoch(6/20) batch: 400 loss: 0.676
# epoch(6/20) batch: 600 loss: 0.664
# epoch(6/20) batch: 800 loss: 0.657
# epoch(6/20) batch: 1000 loss: 0.652
# epoch(6/20) batch: 1200 loss: 0.629
# epoch(6/20) batch: 1400 loss: 0.621
# epoch(6/20) batch: 1600 loss: 0.600
# epoch(6/20) batch: 1800 loss: 0.581
# epoch(6/20) batch: 2000 loss: 0.557
# epoch(6/20) Validation loss: 0.632378483445442
# epoch(7/20) batch: 200 loss: 0.475
# epoch(7/20) batch: 400 loss: 0.480
# epoch(7/20) batch: 600 loss: 0.485
# epoch(7/20) batch: 800 loss: 0.477
# epoch(7/20) batch: 1000 loss: 0.490
# epoch(7/20) batch: 1200 loss: 0.448
# epoch(7/20) batch: 1400 loss: 0.461
# epoch(7/20) batch: 1600 loss: 0.428
# epoch(7/20) batch: 1800 loss: 0.413
# epoch(7/20) batch: 2000 loss: 0.398
# epoch(7/20) Validation loss: 0.41584884166387615
# epoch(8/20) batch: 200 loss: 0.393
# epoch(8/20) batch: 400 loss: 0.365
# epoch(8/20) batch: 600 loss: 0.351
# epoch(8/20) batch: 800 loss: 0.357
# epoch(8/20) batch: 1000 loss: 0.354
# epoch(8/20) batch: 1200 loss: 0.354
# epoch(8/20) batch: 1400 loss: 0.337
# epoch(8/20) batch: 1600 loss: 0.329
# epoch(8/20) batch: 1800 loss: 0.331
# epoch(8/20) batch: 2000 loss: 0.320
# epoch(8/20) Validation loss: 0.36594119615770354
# epoch(9/20) batch: 200 loss: 0.287
# epoch(9/20) batch: 400 loss: 0.268
# epoch(9/20) batch: 600 loss: 0.283
# epoch(9/20) batch: 800 loss: 0.284
# epoch(9/20) batch: 1000 loss: 0.284
# epoch(9/20) batch: 1200 loss: 0.287
# epoch(9/20) batch: 1400 loss: 0.271
# epoch(9/20) batch: 1600 loss: 0.289
# epoch(9/20) batch: 1800 loss: 0.273
# epoch(9/20) batch: 2000 loss: 0.268
# epoch(9/20) Validation loss: 0.26670531183481216
# epoch(10/20) batch: 200 loss: 0.220
# epoch(10/20) batch: 400 loss: 0.219
# epoch(10/20) batch: 600 loss: 0.228
# epoch(10/20) batch: 800 loss: 0.224
# epoch(10/20) batch: 1000 loss: 0.243
# epoch(10/20) batch: 1200 loss: 0.243
# epoch(10/20) batch: 1400 loss: 0.213
# epoch(10/20) batch: 1600 loss: 0.215
# epoch(10/20) batch: 1800 loss: 0.224
# epoch(10/20) batch: 2000 loss: 0.229
# epoch(10/20) Validation loss: 0.21632969954370682
# epoch(11/20) batch: 200 loss: 0.214
# epoch(11/20) batch: 400 loss: 0.197
# epoch(11/20) batch: 600 loss: 0.196
# epoch(11/20) batch: 800 loss: 0.196
# epoch(11/20) batch: 1000 loss: 0.201
# epoch(11/20) batch: 1200 loss: 0.196
# epoch(11/20) batch: 1400 loss: 0.186
# epoch(11/20) batch: 1600 loss: 0.195
# epoch(11/20) batch: 1800 loss: 0.201
# epoch(11/20) batch: 2000 loss: 0.209
# epoch(11/20) Validation loss: 0.1904686558648009
# epoch(12/20) batch: 200 loss: 0.176
# epoch(12/20) batch: 400 loss: 0.177
# epoch(12/20) batch: 600 loss: 0.179
# epoch(12/20) batch: 800 loss: 0.180
# epoch(12/20) batch: 1000 loss: 0.166
# epoch(12/20) batch: 1200 loss: 0.157
# epoch(12/20) batch: 1400 loss: 0.170
# epoch(12/20) batch: 1600 loss: 0.176
# epoch(12/20) batch: 1800 loss: 0.167
# epoch(12/20) batch: 2000 loss: 0.174
# epoch(12/20) Validation loss: 0.2067521517147822
# epoch(13/20) batch: 200 loss: 0.142
# epoch(13/20) batch: 400 loss: 0.137
# epoch(13/20) batch: 600 loss: 0.172
# epoch(13/20) batch: 800 loss: 0.153
# epoch(13/20) batch: 1000 loss: 0.156
# epoch(13/20) batch: 1200 loss: 0.154
# epoch(13/20) batch: 1400 loss: 0.158
# epoch(13/20) batch: 1600 loss: 0.140
# epoch(13/20) batch: 1800 loss: 0.131
# epoch(13/20) batch: 2000 loss: 0.142
# epoch(13/20) Validation loss: 0.15263791982689356
# epoch(14/20) batch: 200 loss: 0.139
# epoch(14/20) batch: 400 loss: 0.131
# epoch(14/20) batch: 600 loss: 0.131
# epoch(14/20) batch: 800 loss: 0.130
# epoch(14/20) batch: 1000 loss: 0.141
# epoch(14/20) batch: 1200 loss: 0.121
# epoch(14/20) batch: 1400 loss: 0.113
# epoch(14/20) batch: 1600 loss: 0.119
# epoch(14/20) batch: 1800 loss: 0.138
# epoch(14/20) batch: 2000 loss: 0.135
# epoch(14/20) Validation loss: 0.1399655050952056
# epoch(15/20) batch: 200 loss: 0.119
# epoch(15/20) batch: 400 loss: 0.112
# epoch(15/20) batch: 600 loss: 0.140
# epoch(15/20) batch: 800 loss: 0.128
# epoch(15/20) batch: 1000 loss: 0.106
# epoch(15/20) batch: 1200 loss: 0.114
# epoch(15/20) batch: 1400 loss: 0.124
# epoch(15/20) batch: 1600 loss: 0.126
# epoch(15/20) batch: 1800 loss: 0.117
# epoch(15/20) batch: 2000 loss: 0.136
# epoch(15/20) Validation loss: 0.13593390943118236
# epoch(16/20) batch: 200 loss: 0.124
# epoch(16/20) batch: 400 loss: 0.114
# epoch(16/20) batch: 600 loss: 0.108
# epoch(16/20) batch: 800 loss: 0.115
# epoch(16/20) batch: 1000 loss: 0.120
# epoch(16/20) batch: 1200 loss: 0.104
# epoch(16/20) batch: 1400 loss: 0.126
# epoch(16/20) batch: 1600 loss: 0.109
# epoch(16/20) batch: 1800 loss: 0.113
# epoch(16/20) batch: 2000 loss: 0.114
# epoch(16/20) Validation loss: 0.11146672545653867
# epoch(17/20) batch: 200 loss: 0.096
# epoch(17/20) batch: 400 loss: 0.099
# epoch(17/20) batch: 600 loss: 0.120
# epoch(17/20) batch: 800 loss: 0.113
# epoch(17/20) batch: 1000 loss: 0.107
# epoch(17/20) batch: 1200 loss: 0.104
# epoch(17/20) batch: 1400 loss: 0.097
# epoch(17/20) batch: 1600 loss: 0.097
# epoch(17/20) batch: 1800 loss: 0.099
# epoch(17/20) batch: 2000 loss: 0.098
# epoch(17/20) Validation loss: 0.12311041845194308
# epoch(18/20) batch: 200 loss: 0.095
# epoch(18/20) batch: 400 loss: 0.098
# epoch(18/20) batch: 600 loss: 0.107
# epoch(18/20) batch: 800 loss: 0.086
# epoch(18/20) batch: 1000 loss: 0.079
# epoch(18/20) batch: 1200 loss: 0.095
# epoch(18/20) batch: 1400 loss: 0.094
# epoch(18/20) batch: 1600 loss: 0.098
# epoch(18/20) batch: 1800 loss: 0.086
# epoch(18/20) batch: 2000 loss: 0.099
# epoch(18/20) Validation loss: 0.11029660311524113
# epoch(19/20) batch: 200 loss: 0.086
# epoch(19/20) batch: 400 loss: 0.093
# epoch(19/20) batch: 600 loss: 0.078
# epoch(19/20) batch: 800 loss: 0.095
# epoch(19/20) batch: 1000 loss: 0.097
# epoch(19/20) batch: 1200 loss: 0.082
# epoch(19/20) batch: 1400 loss: 0.085
# epoch(19/20) batch: 1600 loss: 0.074
# epoch(19/20) batch: 1800 loss: 0.088
# epoch(19/20) batch: 2000 loss: 0.090
# epoch(19/20) Validation loss: 0.10808829301401175
# epoch(20/20) batch: 200 loss: 0.083
# epoch(20/20) batch: 400 loss: 0.098
# epoch(20/20) batch: 600 loss: 0.094
# epoch(20/20) batch: 800 loss: 0.092
# epoch(20/20) batch: 1000 loss: 0.081
# epoch(20/20) batch: 1200 loss: 0.096
# epoch(20/20) batch: 1400 loss: 0.077
# epoch(20/20) batch: 1600 loss: 0.088
# epoch(20/20) batch: 1800 loss: 0.079
# epoch(20/20) batch: 2000 loss: 0.098
# epoch(20/20) Validation loss: 0.09291304876285561
# Finished Training
# CPU times: user 4min 27s, sys: 2min 5s, total: 6min 32s
# Wall time: 3h 43min 38s

# %%
PATH = BASE_DIR / 'models/ac_py_med.pth'
torch.save(net.state_dict(), PATH)

# %%
# Plot the loss graph
train_loss_values = []
step = 10
for i in range(1, len(loss_values)):
    if i % step == step - 1:
        train_loss_values.append(loss_values[i])
        
plt.figure(figsize=(6, 6)) # size of the plot
plt.plot(train_loss_values, label='Training Loss')
plt.plot(val_loss_values, label='Validation Loss')
plt.xlabel('epochs')
plt.ylabel('Loss')
plt.title('Training Loss Over Time')
plt.legend()
custom_x_range = (0, epochs)
plt.xlim(custom_x_range)
plt.show()

# %% [markdown]
# ### TESTING
# Test the trained network on test data

# %%
# %%time

dataiter = iter(testloader)
images, labels = next(dataiter)

# print images
imshow(torchvision.utils.make_grid(images[0:5]))
print('GroundTruth: ', ' '.join(f'{class_names[labels[j]]:5s}' for j in range(5)))
# Out:
# GroundTruth:  felis-catus panthera-tigris architeuthis-dux pavo-cristatus canis-lupus-familiaris
# CPU times: user 626 ms, sys: 138 ms, total: 764 ms
# Wall time: 13.3 s

# %%
# Load the trained model
PATH = BASE_DIR / 'models/ac_med.pth'

net = Net()
net.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %% [markdown]
# Run tests on a subset of test data

# %%
# %%time
outputs = net(images)
_, predicted = torch.max(outputs, 1)
print('Predicted: ', ' '.join(f'{class_names[predicted[j]]:5s}' for j in range(5)))
# Out:
# Predicted:  felis-catus panthera-tigris architeuthis-dux pavo-cristatus canis-lupus-familiaris
# CPU times: user 261 ms, sys: 172 ms, total: 434 ms
# Wall time: 196 ms

# %% [markdown]
# Run test on the entire test data

# %%
# %%time
# Find the test loss
test_running_loss = 0.0
with torch.no_grad():
    for data in testloader:
        test_inputs, test_labels = data
        
        test_outputs = net(test_inputs)
        test_loss = criterion(test_outputs, test_labels)
        test_running_loss += test_loss.item()
print(f'Test Loss: {test_running_loss / len(testloader)}')
# Out:
# Test Loss: 0.09085460033824468
# CPU times: user 1min 15s, sys: 12.6 s, total: 1min 28s
# Wall time: 1min 26s

# %%
# %%time
correct = 0
total = 0
# since we're not training, we don't need to calculate the gradients for our outputs
with torch.no_grad():
    for data in testloader:
        inputs, labels = data
        if inputs.size()[0] != batch_size:
            break
        # calculate outputs by running images through the network
        outputs = net(inputs)
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
print(f'Number of test images: {total}')
print(f'Number of correct predictions: {correct}')
print(f'Accuracy of the network on test images: {100 * correct // total} %')
# Out:
# Number of test images: 17280
# Number of correct predictions: 16863
# Accuracy of the network on test images: 97 %
# CPU times: user 1min 16s, sys: 12.5 s, total: 1min 28s
# Wall time: 1min 26s

# %% [markdown]
# Run test for each class

# %%
# %%time
# prepare to count predictions for each class
correct_pred = {classname: 0 for classname in class_names}
total_pred = {classname: 0 for classname in class_names}

# again no gradients needed
with torch.no_grad():
    for data in testloader:
        inputs, labels = data
            
        outputs = net(inputs)
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[class_names[label]] += 1
            total_pred[class_names[label]] += 1


# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * correct_count / total_pred[classname]
    print(f'Accuracy for class: {classname:5s} is {accuracy:.1f} %')
# Out:
# Accuracy for class: acinonyx-jubatus is 96.9 %
# Accuracy for class: agkistrodon-contortrix is 95.6 %
# Accuracy for class: ailuropoda-melanoleuca is 99.6 %
# Accuracy for class: ailurus-fulgens is 100.0 %
# Accuracy for class: alces-alces is 100.0 %
# Accuracy for class: anas-platyrhynchos is 100.0 %
# Accuracy for class: apis-mellifera is 89.8 %
# Accuracy for class: aptenodytes-forsteri is 94.7 %
# Accuracy for class: aquila-chrysaetos is 94.6 %
# Accuracy for class: ara-macao is 94.9 %
# Accuracy for class: architeuthis-dux is 95.6 %
# Accuracy for class: ardea-herodias is 100.0 %
# Accuracy for class: balaenoptera-musculus is 96.0 %
# Accuracy for class: betta-splendens is 100.0 %
# Accuracy for class: bison-bison is 98.5 %
# Accuracy for class: bos-gaurus is 97.6 %
# Accuracy for class: bos-taurus is 96.9 %
# Accuracy for class: bradypus-variegatus is 92.5 %
# Accuracy for class: branta-canadensis is 97.9 %
# Accuracy for class: canis-lupus is 97.0 %
# Accuracy for class: canis-lupus-familiaris is 95.9 %
# Accuracy for class: carcharodon-carcharias is 89.4 %
# Accuracy for class: cardinalis-cardinalis is 93.5 %
# Accuracy for class: cathartes-aura is 91.3 %
# Accuracy for class: centrochelys-sulcata is 94.5 %
# Accuracy for class: centruroides-vittatus is 92.5 %
# Accuracy for class: ceratitis-capitata is 100.0 %
# Accuracy for class: ceratotherium-simum is 94.7 %
# Accuracy for class: chelonia-mydas is 98.4 %
# Accuracy for class: chrysemys-picta is 100.0 %
# Accuracy for class: coelacanthiformes is 85.7 %
# Accuracy for class: connochaetes-gnou is 94.7 %
# Accuracy for class: correlophus-ciliatus is 89.8 %
# Accuracy for class: crocodylus-niloticus is 100.0 %
# Accuracy for class: crotalus-atrox is 95.8 %
# Accuracy for class: cyanocitta-cristata is 98.2 %
# Accuracy for class: danaus-plexippus is 100.0 %
# Accuracy for class: dasypus-novemcinctus is 98.3 %
# Accuracy for class: delphinapterus-leucas is 100.0 %
# Accuracy for class: dermochelys-coriacea is 97.4 %
# Accuracy for class: desmodus-rotundus is 95.1 %
# Accuracy for class: dugong-dugon is 91.3 %
# Accuracy for class: eidolon-helvum is 100.0 %
# Accuracy for class: enhydra-lutris is 98.2 %
# Accuracy for class: enteroctopus-dofleini is 97.1 %
# Accuracy for class: equus-caballus is 97.8 %
# Accuracy for class: equus-quagga is 97.6 %
# Accuracy for class: eudocimus-albus is 100.0 %
# Accuracy for class: falco-peregrinus is 93.1 %
# Accuracy for class: felis-catus is 98.3 %
# Accuracy for class: formicidae is 95.3 %
# Accuracy for class: gallus-gallus-domesticus is 95.9 %
# Accuracy for class: giraffa-camelopardalis is 96.6 %
# Accuracy for class: gorilla-gorilla is 99.3 %
# Accuracy for class: haliaeetus-leucocephalus is 100.0 %
# Accuracy for class: hapalochlaena-maculosa is 100.0 %
# Accuracy for class: hippopotamus-amphibius is 97.6 %
# Accuracy for class: homo-sapiens is 98.8 %
# Accuracy for class: hydrurga-leptonyx is 100.0 %
# Accuracy for class: icterus-spurius is 94.9 %
# Accuracy for class: iguana-iguana is 96.0 %
# Accuracy for class: lampropeltis-triangulum is 100.0 %
# Accuracy for class: lemur-catta is 97.8 %
# Accuracy for class: lepus-americanus is 97.3 %
# Accuracy for class: loxodonta-africana is 98.7 %
# Accuracy for class: macropus-giganteus is 97.9 %
# Accuracy for class: malayopython-reticulatus is 100.0 %
# Accuracy for class: mammuthus-primigeniu is 96.2 %
# Accuracy for class: martes-americana is 98.1 %
# Accuracy for class: megaptera-novaeangliae is 82.5 %
# Accuracy for class: melanerpes-carolinus is 100.0 %
# Accuracy for class: mellisuga-helenae is 98.8 %
# Accuracy for class: mergus-serrator is 93.1 %
# Accuracy for class: mimus-polyglottos is 96.6 %
# Accuracy for class: monodon-monoceros is 98.0 %
# Accuracy for class: musca-domestica is 98.9 %
# Accuracy for class: odobenus-rosmarus is 83.9 %
# Accuracy for class: ophiophagus-hannah is 96.2 %
# Accuracy for class: orcinus-orca is 100.0 %
# Accuracy for class: ornithorhynchus-anatinus is 97.0 %
# Accuracy for class: ovis-aries is 96.1 %
# Accuracy for class: ovis-canadensis is 97.3 %
# Accuracy for class: panthera-leo is 96.2 %
# Accuracy for class: panthera-onca is 97.2 %
# Accuracy for class: panthera-pardus is 100.0 %
# Accuracy for class: panthera-tigris is 99.4 %
# Accuracy for class: pantherophis-alleghaniensis is 96.6 %
# Accuracy for class: pantherophis-guttatus is 96.9 %
# Accuracy for class: passerina-ciris is 97.7 %
# Accuracy for class: pavo-cristatus is 100.0 %
# Accuracy for class: periplaneta-americana is 96.0 %
# Accuracy for class: phascolarctos-cinereus is 99.0 %
# Accuracy for class: phoenicopterus-ruber is 96.1 %
# Accuracy for class: physalia-physalis is 95.7 %
# Accuracy for class: pongo-abelii is 97.5 %
# Accuracy for class: procyon-lotor is 95.8 %
# Accuracy for class: pteranodon-longiceps is 95.8 %
# Accuracy for class: pterois-mombasae is 97.1 %
# Accuracy for class: pterois-volitans is 95.0 %
# Accuracy for class: puma-concolor is 92.9 %
# Accuracy for class: rattus-rattus is 98.8 %
# Accuracy for class: rusa-unicolor is 97.9 %
# Accuracy for class: sciurus-carolinensis is 100.0 %
# Accuracy for class: spheniscus-demersus is 95.3 %
# Accuracy for class: sphyrna-mokarran is 97.1 %
# Accuracy for class: stegosaurus-stenops is 95.7 %
# Accuracy for class: struthio-camelus is 98.5 %
# Accuracy for class: telmatobufo-bullocki is 100.0 %
# Accuracy for class: triceratops-horridus is 96.6 %
# Accuracy for class: turdus-migratorius is 100.0 %
# Accuracy for class: tursiops-truncatus is 94.7 %
# Accuracy for class: tyrannosaurus-rex is 100.0 %
# Accuracy for class: ursus-arctos-horribilis is 96.0 %
# Accuracy for class: ursus-maritimus is 94.9 %
# Accuracy for class: varanus-komodoensis is 100.0 %
# Accuracy for class: vulpes-vulpes is 91.1 %
# Accuracy for class: vultur-gryphus is 95.3 %
# CPU times: user 1min 16s, sys: 12.6 s, total: 1min 28s
# Wall time: 1min 26s
